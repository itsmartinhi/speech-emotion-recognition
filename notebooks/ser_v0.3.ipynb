# %% [markdown]
# # Speech Emotion Recognition v0.2

# %%
import os

import librosa, librosa.display
import IPython.display as ipd
from random import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras as keras

from scipy import signal
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Fetching the audio data

# %%
# define constants
RAW_DATA_PATH = '../data/Audio_Speech_Actors_01-24/'
PROCESSED_DATA_PICKLE_PATH = '../data/mfcc.pkl'

# %%
dir_path = RAW_DATA_PATH
dir_list = os.listdir(dir_path)
dir_list.sort()
print(dir_list)
# Out:
# ['Actor_01', 'Actor_02', 'Actor_03', 'Actor_04', 'Actor_05', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_10', 'Actor_11', 'Actor_12', 'Actor_13', 'Actor_14', 'Actor_15', 'Actor_16', 'Actor_17', 'Actor_18', 'Actor_19', 'Actor_20', 'Actor_21', 'Actor_22', 'Actor_23', 'Actor_24']

# %% [markdown]
# ### Declaring the labels

# %%
emotion_list = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']
intensity_list = ['normal', 'strong']
statement_list = ['kids', 'dogs']
gender_list = ['female', 'male']

# %%
# Create a DataFrame for Data intel
columns = ['path', 'source', 'actor', 'gender', 'statement', 'repetition', 'intensity', 'emotion']
data_df = pd.DataFrame(columns=columns)

count = 0
for dir in dir_list:
  file_list = os.listdir(dir_path + dir)
  for file in file_list:
    nm = file.split('.')[0].split('-')

    file_path = dir_path + dir + '/' + file
    source = int(nm[1])
    emotion = int(nm[2]) - 1
    intensity = int(nm[3]) - 1
    statement = int(nm[4]) - 1
    repetition = int(nm[5])
    actor = int(nm[6])
    gender = actor%2

    data_df.loc[count] = [file_path, source, actor, gender, statement, repetition, intensity, emotion]
    count += 1

print(len(data_df))
data_df.head(3)
# Out:
# 1440
#                                                 path source actor gender  \
# 0  ../data/Audio_Speech_Actors_01-24/Actor_01/03-...      1     1      1
# 1  ../data/Audio_Speech_Actors_01-24/Actor_01/03-...      1     1      1
# 2  ../data/Audio_Speech_Actors_01-24/Actor_01/03-...      1     1      1
#
#   statement repetition intensity emotion
# 0         0          1         0       0
# 1         0          2         0       0
# 2         1          1         0       0

# %% [markdown]
# ## Plotting the audio file

# %%
# constants
SAMPLE_RATE = 22050

# set plotting style
plt.style.use('dark_background')

# %% [markdown]
# ### Various plots of a random file

# %%
# select a random example
filename = data_df.path[int(random() * len(data_df))]
print(filename)

signal, sr = librosa.load(filename, sr=SAMPLE_RATE)
ipd.Audio(signal, rate=sr)
# Out:
# ../data/Audio_Speech_Actors_01-24/Actor_10/03-01-08-02-02-01-10.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15, 5))
plt.title('Waveform')
plt.xlabel("Time")
plt.ylabel("Amplitude")
librosa.display.waveplot(signal, sr=sr)
plt.show()

# %%
fft = np.fft.fft(signal)
magnitude = np.abs(fft)
frequency = np.linspace(0, sr, len(magnitude))

left_frequency = frequency[:int(len(frequency) / 2)]
left_magnitude = magnitude[:int(len(frequency) / 2)]

plt.figure(figsize=(15, 5))
plt.title('FFT')
plt.plot(left_frequency, left_magnitude)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.show()

# %%
n_fft = 2048  # number of samples per fft
hop_length = 512  # number of samples we shift after each fft

stft = librosa.core.stft(signal, n_fft=n_fft, hop_length=hop_length)
spectrogram = np.abs(stft)

log_spectrogram = librosa.amplitude_to_db(spectrogram)

plt.figure(figsize=(15, 5))
plt.title('STFT')
librosa.display.specshow(log_spectrogram, sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar()
plt.show()

# %%
mfccs = librosa.feature.mfcc(signal, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mfcc=13)

# Let's pad on the first and second deltas while we're at it
delta2_mfcc = librosa.feature.delta(mfccs, order=2)

plt.figure(figsize=(15, 5))
plt.title('MFCCs')
librosa.display.specshow(delta2_mfcc, sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC")
plt.colorbar()
plt.show()

# %% [markdown]
# ### Various plots of a random trimmed file

# %%
trimmed_signal, bb = librosa.effects.trim(signal, top_db=30)
print(len(signal)/SAMPLE_RATE)
print(len(trimmed_signal)/SAMPLE_RATE)
ipd.Audio(trimmed_signal, rate=sr)
# Out:
# 3.6369614512471657
# 1.6718367346938776
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15, 5))
plt.title('Waveform')
plt.xlabel("Time")
plt.ylabel("Amplitude")
librosa.display.waveplot(trimmed_signal, sr=sr)
plt.show()

# %%
n_fft = 2048  # number of samples per fft
hop_length = 512  # number of samples we shift after each fft

stft = librosa.core.stft(trimmed_signal, n_fft=n_fft, hop_length=hop_length)
spectrogram = np.abs(stft)

log_spectrogram = librosa.amplitude_to_db(spectrogram)

plt.figure(figsize=(15, 5))
plt.title('STFT (trimmed)')
librosa.display.specshow(log_spectrogram, sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar()
plt.show()

# %%
mfccs = librosa.feature.mfcc(trimmed_signal, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mfcc=13)

# Let's pad on the first and second deltas while we're at it
delta2_mfcc_trim = librosa.feature.delta(mfccs, order=2)

plt.figure(figsize=(15, 5))
plt.title('MFCCs (trimmed)')
librosa.display.specshow(delta2_mfcc_trim, sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC")
plt.colorbar()
plt.show()

# %% [markdown]
# ## Defining our target labels

# %%
data_df.groupby('emotion')['path'].nunique().plot(kind='bar')

# %%
def extract_features(data_df):

    mfcc_list = []

    for i in tqdm(range(len(data_df))):
        signal, sr = librosa.load(data_df.path[i], sr=SAMPLE_RATE, duration=2.9)

        mfcc = librosa.feature.mfcc(signal, sr=sr, n_mfcc=13, n_fft=2048, hop_length=512)
        mfcc = mfcc.T

        mfcc_list.append(mfcc.tolist())

    data_df['mfcc'] = mfcc_list
    return data_df

# %% [markdown]
# ### Save Feature Data Files

# %%
pickle_file_available = os.path.isfile(PROCESSED_DATA_PICKLE_PATH)

if not pickle_file_available:
    data_df = extract_features(data_df=data_df)

# %%
if not pickle_file_available:
    print('\nSaving Pickle file...')
    data_df.to_pickle(PROCESSED_DATA_PICKLE_PATH)
    print("Pickle file size: {} MB".format(os.path.getsize(PROCESSED_DATA_PICKLE_PATH) / (1024 * 1024)))

# %%
def load_dataframe(dataset_path, use_existing_df=False, df=data_df):

    if not use_existing_df:
        df = pd.read_pickle(dataset_path)

    return df

# %%
data_df = load_dataframe(PROCESSED_DATA_PICKLE_PATH)

# identify too short mfccs
vals = []
for i, val in enumerate(data_df["mfcc"].to_numpy()):
    if len(val) < 130:
        vals.append(i)

data_df = data_df.drop(vals)
data_df = data_df.reset_index(drop=True)
inputs = np.stack(data_df["mfcc"].to_numpy())
targets = np.stack(data_df["emotion"].to_numpy())
targets2 = data_df["emotion"].to_numpy()

inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.2, random_state=42, shuffle=True)

# %%
# build the network architecture
regularizer = keras.regularizers.l2(0.001)
model = keras.Sequential([
    # input layer
    keras.layers.Flatten(input_shape=(inputs.shape[1], inputs.shape[2])),

    # 1st hidden layer
    keras.layers.Dense(512, activation="relu"),
    # keras.layers.Dense(512, activation="relu", kernel_regularizer=regularizer),
    # keras.layers.Dropout(0.3),

    # 2nd hidden layer
    keras.layers.Dense(256, activation="relu"),
    # keras.layers.Dense(256, activation="relu", kernel_regularizer=regularizer),
    # keras.layers.Dropout(0.3),

    # 3rd hidden layer
    keras.layers.Dense(64, activation="relu"),
    # keras.layers.Dense(64, activation="relu", kernel_regularizer=regularizer),
    # keras.layers.Dropout(0.3),

    # output layer
    keras.layers.Dense(8, activation="softmax")
])

# compile network
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])

model.summary()

history = model.fit(
    inputs_train,
    targets_train,
    validation_data=(inputs_test, targets_test),
    epochs=20,
    batch_size=64
)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 1690)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               865792
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 1,014,088
# Trainable params: 1,014,088
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1150 samples, validate on 288 samples
# Epoch 1/20
# 1150/1150 [==============================] - 1s 705us/sample - loss: 47.1051 - accuracy: 0.1626 - val_loss: 25.8812 - val_accuracy: 0.1632
# Epoch 2/20
# 1150/1150 [==============================] - 0s 57us/sample - loss: 17.6618 - accuracy: 0.2617 - val_loss: 16.5340 - val_accuracy: 0.2535
# Epoch 3/20
# 1150/1150 [==============================] - 0s 57us/sample - loss: 11.2952 - accuracy: 0.3270 - val_loss: 12.8280 - val_accuracy: 0.2951
# Epoch 4/20
# 1150/1150 [==============================] - 0s 56us/sample - loss: 8.3943 - accuracy: 0.3896 - val_loss: 9.8803 - val_accuracy: 0.2917
# Epoch 5/20
# 1150/1150 [==============================] - 0s 60us/sample - loss: 6.2773 - accuracy: 0.4539 - val_loss: 9.0702 - val_accuracy: 0.3160
# Epoch 6/20
# 1150/1150 [==============================] - 0s 70us/sample - loss: 4.9947 - accuracy: 0.5070 - val_loss: 8.6654 - val_accuracy: 0.3681
# Epoch 7/20
# 1150/1150 [==============================] - 0s 62us/sample - loss: 3.8970 - accuracy: 0.5504 - val_loss: 7.1403 - val_accuracy: 0.3646
# Epoch 8/20
# 1150/1150 [==============================] - 0s 59us/sample - loss: 3.3329 - accuracy: 0.5774 - val_loss: 8.6045 - val_accuracy: 0.3889
# Epoch 9/20
# 1150/1150 [==============================] - 0s 59us/sample - loss: 3.1839 - accuracy: 0.5748 - val_loss: 7.5788 - val_accuracy: 0.4097
# Epoch 10/20
# 1150/1150 [==============================] - 0s 57us/sample - loss: 2.3064 - accuracy: 0.6496 - val_loss: 7.5063 - val_accuracy: 0.3924
# Epoch 11/20
# 1150/1150 [==============================] - 0s 71us/sample - loss: 1.9635 - accuracy: 0.6904 - val_loss: 6.7829 - val_accuracy: 0.4028
# Epoch 12/20
# 1150/1150 [==============================] - 0s 60us/sample - loss: 2.1062 - accuracy: 0.6843 - val_loss: 6.6249 - val_accuracy: 0.4549
# Epoch 13/20
# 1150/1150 [==============================] - 0s 59us/sample - loss: 1.6355 - accuracy: 0.7243 - val_loss: 6.5453 - val_accuracy: 0.4167
# Epoch 14/20
# 1150/1150 [==============================] - 0s 60us/sample - loss: 1.3186 - accuracy: 0.7435 - val_loss: 6.6597 - val_accuracy: 0.4410
# Epoch 15/20
# 1150/1150 [==============================] - 0s 57us/sample - loss: 1.2665 - accuracy: 0.7513 - val_loss: 7.1310 - val_accuracy: 0.4306
# Epoch 16/20
# 1150/1150 [==============================] - 0s 69us/sample - loss: 0.9548 - accuracy: 0.7887 - val_loss: 6.0433 - val_accuracy: 0.4167
# Epoch 17/20
# 1150/1150 [==============================] - 0s 62us/sample - loss: 0.7309 - accuracy: 0.8357 - val_loss: 6.1901 - val_accuracy: 0.4236
# Epoch 18/20
# 1150/1150 [==============================] - 0s 57us/sample - loss: 0.7658 - accuracy: 0.8243 - val_loss: 6.4247 - val_accuracy: 0.4514
# Epoch 19/20
# 1150/1150 [==============================] - 0s 58us/sample - loss: 0.5498 - accuracy: 0.8574 - val_loss: 6.4390 - val_accuracy: 0.3924
# Epoch 20/20
# 1150/1150 [==============================] - 0s 56us/sample - loss: 0.4641 - accuracy: 0.8713 - val_loss: 6.4220 - val_accuracy: 0.4097

# %%
def plot_history(history):

    fig, axs = plt.subplots(2)

    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error subplot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
plot_history(history)

# %%
# test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
# print("Accuracy on test set is: {}".format(test_accuracy))

x = inputs_test[42:52]
emo = targets_test[42:52]

model.predict_classes(x)
# Out:
# array([1, 3, 1, 6, 0, 6, 6, 6, 6, 2], dtype=int64)

# %%
exit()

time_list = []
time_list2 = []
sample_list = []

for i in tqdm(range(len(data_df))):
    signal, sr = librosa.load(data_df.path[i], sr=SAMPLE_RATE)
    signalt, index = librosa.effects.trim(signal, top_db=30)
    x = librosa.get_duration(signal)
    y = librosa.get_duration(signalt)
    time_list.append(x)
    time_list2.append(y)
    sample_list.append(len(signal))
# Out:
# 100%|██████████| 1440/1440 [03:06<00:00,  7.73it/s]

# %%
plt.plot(time_list)
plt.show()

# %%
plt.plot(time_list2)
plt.show()

# %%
plt.plot(sample_list)
plt.show()

# %%
tl2 = np.array(time_list2)

# print(np.array(time_list).min())
print(tl2.min())
print(tl2.mean())
print(tl2.max())

# print(np.array(sample_list).min())
#
# print(np.array(sample_list).min()/SAMPLE_RATE)
# Out:
# 1.0913378684807256
# 1.8739459246661627
# 4.250294784580499
