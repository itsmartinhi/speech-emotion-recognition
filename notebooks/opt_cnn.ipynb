# %%
import os

import librosa, librosa.display
import IPython.display as ipd
from random import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras as keras

from scipy import signal
from sklearn.model_selection import train_test_split
from tqdm import tqdm

PROCESSED_DATA_PICKLE_PATH = '../data/df_normal.pkl'

EMOTIONS = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

MFCC_LENGTH = 125

# %%
def load_data(data_path):
    df = pd.read_pickle(data_path)

    # clean up data
    # vals = []
    # for i, val in enumerate(df["mfcc"].to_numpy()):
    #     if len(val) < MFCC_LENGTH:
    #         vals.append(i)
    #
    # df = df.drop(vals)
    # df = df.reset_index(drop=True)

    X = np.stack(df["mfcc"].to_numpy())
    y = np.stack(df["emotion"].to_numpy())

    return X, y

# %%
def prepare_datasets(test_size, validation_size):

    # load data
    X, y = load_data(PROCESSED_DATA_PICKLE_PATH)

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

    # create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # 3d array -> (130, 13, 1)
    X_train = X_train[..., np.newaxis] # 4d array -> (number_samples, 130, 13, 1)
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)



data_df = pd.read_pickle(PROCESSED_DATA_PICKLE_PATH)

df_train, df_test = train_test_split(data_df, test_size=0.2, random_state=42, shuffle=True)

X_train = np.stack(df_train['mfcc'].to_numpy())
X_train = X_train[..., np.newaxis]
y_train = np.stack(df_train['emotion'].to_numpy())

X_test = np.stack(df_test['mfcc'].to_numpy())
X_test = X_test[..., np.newaxis]
y_test = np.stack(df_test['emotion'].to_numpy())

# %%
def build_model(input_shape):

    # create model
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization(axis=1))

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization(axis=1))

    # flatten the output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(8, activation='softmax'))

    return model

input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
model = build_model(input_shape)

# compile network
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])

model.summary()

history = model.fit(
    X_train,
    y_train,
    # validation_data=(X_validation, y_validation),
    validation_data=(X_test, y_test),
    epochs=150,
    batch_size=16
)


# evaluate the CNN on the test set
test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print("Accuracy on test set is: {}".format(str(round(100 * test_accuracy, 2))))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 129, 11, 32)       320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 65, 6, 32)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 65, 6, 32)         260
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 63, 4, 32)         9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 2, 32)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 2, 32)         128
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                131136
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 145,772
# Trainable params: 145,578
# Non-trainable params: 194
# _________________________________________________________________
# Train on 1152 samples, validate on 288 samples
# Epoch 1/150
# 1152/1152 [==============================] - 1s 1ms/sample - loss: 2.1512 - accuracy: 0.1441 - val_loss: 2.0988 - val_accuracy: 0.1146
# Epoch 2/150
# 1152/1152 [==============================] - 0s 252us/sample - loss: 2.0359 - accuracy: 0.1849 - val_loss: 2.0013 - val_accuracy: 0.1979
# Epoch 3/150
# 1152/1152 [==============================] - 0s 268us/sample - loss: 1.9477 - accuracy: 0.2509 - val_loss: 1.8857 - val_accuracy: 0.2986
# Epoch 4/150
# 1152/1152 [==============================] - 0s 251us/sample - loss: 1.9323 - accuracy: 0.2422 - val_loss: 1.8434 - val_accuracy: 0.3576
# Epoch 5/150
# 1152/1152 [==============================] - 0s 260us/sample - loss: 1.8575 - accuracy: 0.2899 - val_loss: 1.7661 - val_accuracy: 0.3715
# Epoch 6/150
# 1152/1152 [==============================] - 0s 302us/sample - loss: 1.8005 - accuracy: 0.3038 - val_loss: 1.7057 - val_accuracy: 0.3924
# Epoch 7/150
150
# 1152/1152 [==============================] - 0s 258us/sample - loss: 0.0790 - accuracy: 0.9757 - val_loss: 1.1032 - val_accuracy: 0.6979
# Epoch 141/150
# 1152/1152 [==============================] - 0s 257us/sample - loss: 0.0586 - accuracy: 0.9818 - val_loss: 1.1428 - val_accuracy: 0.7049
# Epoch 142/150
# 1152/1152 [==============================] - 0s 301us/sample - loss: 0.0616 - accuracy: 0.9783 - val_loss: 1.1236 - val_accuracy: 0.6771
# Epoch 143/150
# 1152/1152 [==============================] - 0s 284us/sample - loss: 0.0674 - accuracy: 0.9800 - val_loss: 1.0966 - val_accuracy: 0.7049
# Epoch 144/150
# 1152/1152 [==============================] - 0s 257us/sample - loss: 0.0660 - accuracy: 0.9818 - val_loss: 1.1554 - val_accuracy: 0.7014
# Epoch 145/150
# 1152/1152 [==============================] - 0s 280us/sample - loss: 0.0695 - accuracy: 0.9774 - val_loss: 1.1236 - val_accuracy: 0.7292
# Epoch 146/150
# 1152/1152 [==============================] - 0s 296us/sample - loss: 0.0730 - accuracy: 0.9766 - val_loss: 1.1773 - val_accuracy: 0.6944
# Epoch 147/150
# 1152/1152 [==============================] - 0s 258us/sample - loss: 0.0530 - accuracy: 0.9878 - val_loss: 1.1479 - val_accuracy: 0.7049
# Epoch 148/150
# 1152/1152 [==============================] - 0s 261us/sample - loss: 0.0571 - accuracy: 0.9809 - val_loss: 1.1588 - val_accuracy: 0.6840
# Epoch 149/150
# 1152/1152 [==============================] - 0s 265us/sample - loss: 0.0685 - accuracy: 0.9809 - val_loss: 1.1813 - val_accuracy: 0.7153
# Epoch 150/150
# 1152/1152 [==============================] - 0s 295us/sample - loss: 0.0724 - accuracy: 0.9774 - val_loss: 1.1650 - val_accuracy: 0.6910
# 288/288 [==============================] - 0s 507us/sample - loss: 1.1650 - accuracy: 0.6910
# Accuracy on test set is: 69.1

# %%
# calc average performance

# acc_list = []
#
# for i in range(1, 21):
#     input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
#     model = build_model(input_shape)
#
#     # compile network
#     optimizer = keras.optimizers.Adam(learning_rate=0.0001)
#     model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])
#
#     # model.summary()
#
#     history = model.fit(
#         X_train,
#         y_train,
#         # validation_data=(X_validation, y_validation),
#         validation_data=(X_test, y_test),
#         epochs=90,
#         batch_size=16,
#         verbose=0
#     )
#
#     # evaluate the CNN on the test set
#     test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
#     print("Accuracy on test set is: {}".format(str(round(100 * test_accuracy, 2))))
#
#     if test_accuracy > 0.7:
#         model.save("../models/cnn_top_performing_run{}.h5".format(i))
#         print("Model saved in run {}".format(i))
#
#     acc_list.append(str(round(100 * test_accuracy, 2)))

# %%
def predict(model, X, y):

    X = X[np.newaxis, ...]

    # prediction = [ [0.1, 0.2, ...] ]
    prediction = model.predict_classes(X)[0] # X -> (130, 13, 1)

    print("Expected Emotion: {}, Predicted Emotion: {}".format(EMOTIONS[y], EMOTIONS[prediction]))


# make prediction on a sample
X = X_test[69]
y = y_test[69]
predict(model, X, y)
# Out:
# Expected Emotion: sad, Predicted Emotion: fearful

# %%
def plot_history(history):

    fig, axs = plt.subplots(2)

    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Präzision")
    axs[0].set_xlabel("Epoche")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy Evaluation")

    # create error subplot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoche")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error Evaluation")

    plt.tight_layout()
    plt.show()
    # plt.savefig('../plots/cnn_150_epochs_with_anti-overfitting_and_batchnorm.png')

# %%
#model.save("../models/cnn_top_performing.h5")

# %%
plot_history(history)
